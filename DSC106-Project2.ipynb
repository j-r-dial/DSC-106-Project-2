# %% [markdown]
# # DSC 106 Final Visualizaions Code

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# **Our Proposition:** The Geographic access to abortion across US states is deeply unequal and unfair depending on your Geographic location.

# %%
data = {
    "Code": [
        "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "DC", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME",
        "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI",
        "SC", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"
    ],
    "Status": [
        "Total Ban", "No Gestational Limit", "Later-Term Limits", "Total Ban", "Later-Term Limits", "No Gestational Limit",
        "Later-Term Limits", "Later-Term Limits", "No Gestational Limit", "6-Week Early Ban", "6-Week Early Ban", "Later-Term Limits",
        "Total Ban", "Later-Term Limits", "Total Ban", "6-Week Early Ban", "12-18 Week Mid-Ban", "Total Ban", "Total Ban", "Later-Term Limits",
        "No Gestational Limit", "Later-Term Limits", "No Gestational Limit", "No Gestational Limit", "Total Ban", "Later-Term Limits",
        "Later-Term Limits", "12-18 Week Mid-Ban", "Later-Term Limits", "Later-Term Limits", "No Gestational Limit", "No Gestational Limit",
        "Later-Term Limits", "12-18 Week Mid-Ban", "Total Ban", "12-18 Week Mid-Ban", "Total Ban", "No Gestational Limit", "Later-Term Limits",
        "Later-Term Limits", "6-Week Early Ban", "Total Ban", "Total Ban", "Total Ban", "12-18 Week Mid-Ban", "No Gestational Limit",
        "Later-Term Limits", "Later-Term Limits", "Total Ban", "Later-Term Limits", "6-Week Early Ban"
    ]
}

df = pd.DataFrame(data)

fig = px.choropleth(
    df,
    locations='Code',
    locationmode="USA-states",
    color='Status',
    scope="usa",
    color_discrete_map={
        "Total Ban": "#800000",          
        "6-Week Early Ban": "#e31a1c",  
        "12-18 Week Mid-Ban": "#fd8d3c", 
        "Later-Term Limits": "#fed976", 
        "No Gestational Limit": "#238b45"
    },
    category_orders={
        "Status": [
            "Total Ban",
            "6-Week Early Ban",
            "12-18 Week Mid-Ban",
            "Later-Term Limits",
            "No Gestational Limit"
        ]
    },
    title="<b>The U.S. Healthcare Lottery:</b> Geographic Inequality in Abortion Access (2025)"
)

fig.add_trace(
    go.Scattergeo(
        locations=df['Code'],
        locationmode="USA-states",
        text=df['Code'],
        mode='text',
        textfont=dict(color="black", size=8),
        showlegend=False
    )
)

fig.update_layout(
    margin={"r":0,"t":80,"l":0,"b":0},
    title_x=0.5,
    legend_title_text='<b>Legal Status</b>',
    legend=dict(
        yanchor="top",
        y=0.9,
        xanchor="left",
        x=0.9
    )
)

fig.show()

# %% [markdown]
# **Opposing Proposition:** Geographic access to abortion care varies by state, but it is not as dramatic as it may seem.

# %%
df = pd.read_csv("/Users/hannahhuangh/Desktop/DSC106/Project-2/Abortion-Data.csv")

plot_df = df[["U.S. State", "No. of abortion clinics, 2020"]].copy()
plot_df.columns = ["state", "num_clinics"]

plot_df["num_clinics"] = (
    plot_df["num_clinics"]
    .astype(str)
    .str.replace(",", "", regex=False)
    .str.strip()
)

plot_df["num_clinics"] = pd.to_numeric(plot_df["num_clinics"], errors="coerce")

state_abbrev = {
    "Alabama": "AL", "Alaska": "AK", "Arizona": "AZ", "Arkansas": "AR",
    "California": "CA", "Colorado": "CO", "Connecticut": "CT", "Delaware": "DE",
    "Florida": "FL", "Georgia": "GA", "Hawaii": "HI", "Idaho": "ID",
    "Illinois": "IL", "Indiana": "IN", "Iowa": "IA", "Kansas": "KS",
    "Kentucky": "KY", "Louisiana": "LA", "Maine": "ME", "Maryland": "MD",
    "Massachusetts": "MA", "Michigan": "MI", "Minnesota": "MN", "Mississippi": "MS",
    "Missouri": "MO", "Montana": "MT", "Nebraska": "NE", "Nevada": "NV",
    "New Hampshire": "NH", "New Jersey": "NJ", "New Mexico": "NM", "New York": "NY",
    "North Carolina": "NC", "North Dakota": "ND", "Ohio": "OH", "Oklahoma": "OK",
    "Oregon": "OR", "Pennsylvania": "PA", "Rhode Island": "RI", "South Carolina": "SC",
    "South Dakota": "SD", "Tennessee": "TN", "Texas": "TX", "Utah": "UT",
    "Vermont": "VT", "Virginia": "VA", "Washington": "WA", "West Virginia": "WV",
    "Wisconsin": "WI", "Wyoming": "WY", "District of Columbia": "DC"
}

state_area_sq_miles = {
    "Alabama": 52420, "Alaska": 665384, "Arizona": 113990, "Arkansas": 53179,
    "California": 163695, "Colorado": 104094, "Connecticut": 5543, "Delaware": 2489,
    "Florida": 65758, "Georgia": 59425, "Hawaii": 10932, "Idaho": 83569,
    "Illinois": 57914, "Indiana": 36420, "Iowa": 56273, "Kansas": 82278,
    "Kentucky": 40408, "Louisiana": 52378, "Maine": 35380, "Maryland": 12406,
    "Massachusetts": 10554, "Michigan": 96714, "Minnesota": 86936, "Mississippi": 48432,
    "Missouri": 69707, "Montana": 147040, "Nebraska": 77348, "Nevada": 110572,
    "New Hampshire": 9349, "New Jersey": 8723, "New Mexico": 121590, "New York": 54555,
    "North Carolina": 53819, "North Dakota": 70698, "Ohio": 44826, "Oklahoma": 69899,
    "Oregon": 98379, "Pennsylvania": 46054, "Rhode Island": 1545, "South Carolina": 32020,
    "South Dakota": 77116, "Tennessee": 42144, "Texas": 268596, "Utah": 84897,
    "Vermont": 9616, "Virginia": 42775, "Washington": 71298, "West Virginia": 24230,
    "Wisconsin": 65496, "Wyoming": 97813, "District of Columbia": 68
}

plot_df["abbr"] = plot_df["state"].map(state_abbrev)
plot_df["area_sq_miles"] = plot_df["state"].map(state_area_sq_miles)

plot_df["clinics_per_1000_sq_miles"] = (
    plot_df["num_clinics"] / plot_df["area_sq_miles"] * 1000
)

plot_df = plot_df.dropna(
    subset=["abbr", "num_clinics", "area_sq_miles", "clinics_per_1000_sq_miles"]
)

fig = px.choropleth(
    plot_df,
    locations="abbr",
    locationmode="USA-states",
    color="clinics_per_1000_sq_miles",
    scope="usa",
    hover_name="state",
    hover_data={
        "num_clinics": True,
        "area_sq_miles": True,
        "clinics_per_1000_sq_miles": ":.2f",
        "abbr": False
    },
    color_continuous_scale="Blues",
    range_color=(0, 20),
    labels={
        "clinics_per_1000_sq_miles": "Clinics per 1,000 sq. miles"
    },
    title="Number of Abortion Clinics per 1,000 Square Miles (2020)"
)

fig.update_traces(
    marker_line_color="white",
    marker_line_width=0.7
)

fig.update_layout(
    width=1100,
    height=700,
    margin=dict(l=20, r=20, t=90, b=20),
    title_x=0.5,
    font=dict(
        family="Arial",
        size=15,
        color="#1f2937"
    ),
    title_font=dict(
        family="Arial",
        size=26,
        color="#1f2937"
    ),
    coloraxis_colorbar=dict(
        title=dict(
            text="Clinics per<br>1,000 sq. mi.",
            font=dict(size=14)
        ),
        tickfont=dict(size=12)
    )
)

fig.add_scattergeo(
    locations=plot_df["abbr"],
    locationmode="USA-states",
    text=plot_df["abbr"],
    mode="text",
    textfont=dict(
        family="Arial",
        size=9,
        color="#111827"
    ),
    hoverinfo="skip"
)

fig.show()
